# %%
import os
# from path import Path

# %% [markdown]
# # Testing base64 img to actual image

# %%
os.chdir("..")

# %%
from app_utils import *

# %%
path = "temp.jpg"

# %%
base64_2_img(image,path)

# %% [markdown]
# # Testing image to base 64

# %%
image64 = image_2_base64("temp.jpg")

# %%
base64_2_img(image64,"temp2.jpg")

# %%
image64.decode("utf-8")
# Out:
# '...'

# %%
type(image64)
# Out:
# bytes

# %%
type(image)
# Out:
# str

# %%
import json
